# %% [markdown]
# # 🚗 **Assignment: Exploratory Data Analysis (EDA) of Car Data** 🚗
#
#
# ## **Objective:** 🎯
#
# The objective of this exciting assignment is to embark on an Exploratory Data Analysis (EDA) with a car dataset (**automobiles.csv**).

# %% [markdown]
# ## Ouput Should Look Like This :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="matplotlib")

# %%
# Import dataset
dataset = pd.read_csv("automobiles.csv")
dataset
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 0            2                164   audi       gas        std         four
# 1            2                164   audi       gas        std         four
# 2            1                158   audi       gas        std         four
# 3            1                158   audi       gas      turbo         four
# 4            2                192    bmw       gas        std          two
# ..         ...                ...    ...       ...        ...          ...
# 154         -1                 95  volvo       gas        std         four
# 155         -1                 95  volvo       gas      turbo         four
# 156         -1                 95  volvo       gas        std         four
# 157         -1                 95  volvo    diesel      turbo         four
# 158         -1                 95  volvo       gas      turbo         four
#
# ...

# %%
# Check summary of data
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          159 non-null    int64
#  1   normalized-losses  159 non-null    int64
#  2   make               159 non-null    object
#  3   fuel-type          159 non-null    object
#  4   aspiration         159 non-null    object
#  5   num-of-doors       159 non-null    object
#  6   body-style         159 non-null    object
#  7   drive-wheels       159 non-null    object
#  8   engine-location    159 non-null    object
#  9   wheel-base         159 non-null    float64
#  10  length             159 non-null    float64
#  11  width              159 non-null    float64
#  12  height             159 non-null    float64
#  13  curb-weight        159 non-null    int64
#  14  engine-type        159 non-null    object
#  15  num-of-cylinders   159 non-null    object
# ...

# %%
# Check duplicate values
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Check unique values of cars
dataset["make"].unique()
# Out:
# array(['audi', 'bmw', 'chevrolet', 'dodge', 'honda', 'jaguar', 'mazda',
#        'mercedes-benz', 'mitsubishi', 'nissan', 'peugot', 'plymouth',
#        'porsche', 'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'],
#       dtype=object)

# %% [markdown]
# # Visualize the horse power with price

# %%
sns.set_style('darkgrid')
sns.set_context('notebook')
sns.relplot(x = 'horsepower', y = "price", data = dataset, hue = 'fuel-type', col = 'num-of-doors', style = 'num-of-cylinders',\
           size = 'engine-size', sizes = (0,250), color = 'red')

# Ignoring the warning
warnings.filterwarnings("ignore", message="The figure layout has changed to tight")

plt.show()

# As per analysis in this graph we can see that we have high price car in two doors and it have eight cylinders and engine size 
# is aprroximately 160 with the 160 horspower

# %%
pd.set_option('display.max_columns', None)
dataset.head()
# Out:
#    symboling  normalized-losses  make fuel-type aspiration num-of-doors  \
# 0          2                164  audi       gas        std         four
# 1          2                164  audi       gas        std         four
# 2          1                158  audi       gas        std         four
# 3          1                158  audi       gas      turbo         four
# 4          2                192   bmw       gas        std          two
#
#   body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 0      sedan          fwd           front        99.8   176.6   66.2    54.3
# 1      sedan          4wd           front        99.4   176.6   66.4    54.3
# 2      sedan          fwd           front       105.8   192.7   71.4    55.7
# 3      sedan          fwd           front       105.8   192.7   71.4    55.9
# 4      sedan          rwd           front       101.2   176.8   64.8    54.3
#
# ...

# %%
dataset["engine-type"].unique()
# Out:
# array(['ohc', 'l', 'dohc', 'ohcv', 'ohcf'], dtype=object)

# %%
sns.reset_defaults()
sns.barplot(data = dataset, x = 'make', y = 'price')

plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Check frequency of cars

# %%
#sns.reset_defaults()
plt.figure(figsize = (10,6))
sns.set_style('darkgrid')
ax = sns.histplot(data = dataset, x = 'make', hue = 'body-style', )


plt.xticks(rotation = 90)
plt.show()
